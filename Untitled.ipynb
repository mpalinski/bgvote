# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('./data/bgg2000.csv')

# %%
df.rename(columns={'name':'gierki'},inplace=True)

# %%
df.to_csv('./data/bgg')
# Out:
#       rank                                     bgg_url  game_id  \
# 0        1  https://boardgamegeek.com/boardgame/224517   224517
# 1        2  https://boardgamegeek.com/boardgame/161936   161936
# 2        3  https://boardgamegeek.com/boardgame/174430   174430
# 3        4  https://boardgamegeek.com/boardgame/342942   342942
# 4        5  https://boardgamegeek.com/boardgame/233078   233078
# ...    ...                                         ...      ...
# 1995  1996    https://boardgamegeek.com/boardgame/7858     7858
# 1996  1997  https://boardgamegeek.com/boardgame/156496   156496
# 1997  1998     https://boardgamegeek.com/boardgame/472      472
# 1998  1999  https://boardgamegeek.com/boardgame/189660   189660
# 1999  2000   https://boardgamegeek.com/boardgame/19526    19526
#
#                                      gierki  min_players  max_players  \
# 0                         Brass: Birmingham            2            4
# ...
